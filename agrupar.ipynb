# %%
import pandas as pd
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, MeanShift
from sklearn.preprocessing import MinMaxScaler

# %%
dados = pd.read_csv("nbb.csv")
columns = []
names = []
for cl in dados.columns:
    cln = cl.split(".")[0]
    if cln not in columns:
        names.append("_".join(cln.split(" ")).lower())
        columns.append(cl) 

dados = dados[columns]
dados.columns = names

# %%
dados
# Out:
#              jogadores  jogo  min_em_quadra  pontos  cesta_de_3_pts  \
# 0       McClanahan #22    32          34.50   21.44            6.19
# 1          Antonio #11    38          32.13   17.55            5.68
# 2        Lucas Dias #9    38          31.55   17.29            6.16
# 3    Lucas Mariano #28    44          27.24   17.07            6.61
# 4            Thomas #0    34          32.00   17.00            4.94
# ..                 ...   ...            ...     ...             ...
# 249           Motta #0     3           2.06    0.00            0.00
# 250       João Mini #1     3           1.74    0.00            0.00
# 251        Paschoal #8     4           3.08    0.00            0.00
# 252      Gusthavo S #6    12           1.37    0.00            0.00
# 253         Thiago #20    13           2.10    0.00            0.00
#
#      cesta_de_2_pts  lances_livres  rebotes  rebotes_ofensivos  \
# 0             11.06           4.19     3.59               0.69
# 1              8.58           3.29     4.84               4.84
# 2              8.79           2.34     7.42               7.42
# 3              7.50           2.95     5.50               5.50
# 4              8.24           3.82     4.79               4.79
# ..              ...            ...      ...                ...
# 249            0.00           0.00     0.00               0.00
# 250            0.00           0.00     0.00               0.00
# 251            0.00           0.00     0.50               0.50
# 252            0.00           0.00     0.00               0.00
# 253            0.00           0.00     0.23               0.23
#
#      rebotes_defensivos  ...  tocos  faltas_cometidas  \
# 0                  2.91  ...   0.19              2.69
# 1                  3.16  ...   0.26              2.71
# 2                  5.63  ...   0.53              2.13
# 3                  4.07  ...   0.32              1.91
# 4                  4.26  ...   0.38              2.41
# ..                  ...  ...    ...               ...
# 249                0.00  ...   0.00              0.00
# 250                0.00  ...   0.00              0.00
# 251                0.25  ...   0.00              0.00
# 252                0.00  ...   0.00              0.17
# 253                0.23  ...   0.00              0.08
#
#      índice_de_tocos_por_faltas_cometidas  \
# 0                                    0.07
# 1                                    0.10
# 2                                    0.25
# 3                                    0.17
# 4                                    0.16
# ..                                    ...
# 249                                  1.00
# 250                                  1.00
# 251                                  1.00
# 252                                  0.00
# 253                                  0.00
#
#      total_de_erros_(soma_de_erros_e_violações)  violações  eficiência  \
# 0                                          2.31       0.50       14.50
# 1                                          2.00       0.34       14.66
# 2                                          1.87       0.18       19.92
# 3                                          1.68       0.14       15.77
# 4                                          3.82       0.65       15.15
# ..                                          ...        ...         ...
# 249                                        0.33       0.00       -0.33
# 250                                        0.33       0.33       -0.67
# 251                                        0.25       0.25       -0.50
# 252                                        0.00       0.00       -0.50
# 253                                        0.31       0.08       -0.15
#
#      assistência  bolas_recuperadas_  duplos_duplos  triplos_duplos
# 0           1.75                1.09           0.00            0.00
# 1           1.29                0.84           0.05            0.00
# 2           2.42                0.79           0.24            0.03
# 3           1.52                0.82           0.07            0.00
# 4           3.88                1.15           0.03            0.00
# ..           ...                 ...            ...             ...
# 249         0.33                0.67           0.00            0.00
# 250         0.00                0.00           0.00            0.00
# 251         0.00                0.00           0.00            0.00
# 252         0.00                0.08           0.00            0.00
# 253         0.00                0.08           0.00            0.00
#
# [254 rows x 35 columns]
